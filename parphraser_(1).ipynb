# %% [markdown]
# # **AI-Powered Paraphrasing Tool using Transformers**
# ---
# ---
#
# ## Module End Assignment – Generative AI
# ### Author: Fathima Salga
# ### Tools Used: Python, Hugging Face Transformers, PyTorch

# %% [markdown]
# ##  Project Objective:
# ---
#
# The goal of this project is to develop an AI-powered paraphrasing tool that:
#
# - Takes input text
# - Generates a paraphrased version
# - Preserves semantic meaning
# - Improves clarity and fluency
# - Evaluates output quality using NLP metrics
#
# This system is built using transformer-based deep learning models.

# %% [markdown]
# ## **1. Introduction**
# ---
#
# ### What is Paraphrasing?
#
# Paraphrasing is the process of rewriting text in a different way while preserving its original meaning.
#
# It is widely used in:
# - Content creation
# - Plagiarism reduction
# - Text summarization
# - Academic writing
# - Chatbots and conversational AI
#
#
#
# ### Why Use AI for Paraphrasing?
#
# Traditional NLP models struggle with contextual understanding.
#
# Transformers:
# - Use self-attention mechanisms
# - Understand context better
# - Generate fluent text
# - Process words in parallel

# %%
# !pip install transformers torch sentencepiece nltk rouge-score sentence-transformers language-tool-python
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Collecting rouge-score
#   Using cached rouge_score-0.1.2-py3-none-any.whl
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.3.0)
# Collecting language-tool-python
#   Using cached language_tool_python-3.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.4.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from language-tool-python) (2.32.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from language-tool-python) (5.9.5)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from language-tool-python) (0.10.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->language-tool-python) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->language-tool-python) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->language-tool-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->language-tool-python) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)
# Using cached language_tool_python-3.3.0-py3-none-any.whl (53 kB)
# Installing collected packages: rouge-score, language-tool-python
# Successfully installed language-tool-python-3.3.0 rouge-score-0.1.2

# %% [markdown]
# ## **2. Transformer Architecture**
# ---
#
# ### What is a Transformer?
#
# A Transformer is a deep learning model that uses:
#
# - Self-attention mechanism
# - Multi-head attention
# - Encoder-decoder architecture
#
# Unlike RNNs, transformers process all words simultaneously.
#
#
#
# ### Why T5 Model?
#
# T5 (Text-To-Text Transfer Transformer):
#
# - Treats every NLP task as text generation
# - Converts tasks into text-to-text format
# - Performs well in paraphrasing tasks
#
# Example:
# Input: "paraphrase: Artificial Intelligence is powerful."
# Output: "AI is a powerful technology."

# %%
# Import Essential Libraries
#----------------------------
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
from rouge_score import rouge_scorer
from sentence_transformers import SentenceTransformer, util
import language_tool_python
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## **3. Methodology**
# ---
#
# 1. Model Loading
#
#
# 2. Text Generation

# %% [markdown]
# ##3.1 Model Loading
#
# In this step, we load:
#
# 1. T5 Paraphrasing Model
# 2. Sentence Transformer (for similarity scoring)
# 3. LanguageTool (for grammar correction)
#
# We load a fine-tuned T5 paraphrasing model from Hugging Face.
#
# Model Used:
# - **ramsrigouthamg/t5_paraphraser**

# %%
# Load Models
#-------------------

print("Loading models... Please wait.")

tokenizer = T5Tokenizer.from_pretrained("ramsrigouthamg/t5_paraphraser")
model = T5ForConditionalGeneration.from_pretrained("ramsrigouthamg/t5_paraphraser")

similarity_model = SentenceTransformer('all-MiniLM-L6-v2')
grammar_tool = language_tool_python.LanguageTool('en-US')

print("Models loaded successfully!")
# Out:
# Loading models... Please wait.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/260 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie shared.weight to encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie shared.weight to decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   0%|          | 0.00/259M [00:00<?, ?B/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   0%|          | 32.8k/259M [00:00<18:02, 239kB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   0%|          | 98.3k/259M [00:00<11:57, 360kB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   0%|          | 213k/259M [00:00<07:44, 557kB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   0%|          | 442k/259M [00:00<04:32, 946kB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   0%|          | 901k/259M [00:00<02:31, 1.70MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   1%|          | 1.82M/259M [00:00<01:18, 3.25MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   1%|▏         | 3.67M/259M [00:01<00:40, 6.24MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   2%|▏         | 5.10M/259M [00:01<00:31, 8.08MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   2%|▏         | 6.03M/259M [00:01<00:30, 8.19MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   3%|▎         | 6.89M/259M [00:01<00:30, 8.15MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:   3%|▎         | 7.88M/259M [00:01<00:29, 8.54MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:
0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  50%|█████     | 129M/259M [00:08<00:06, 19.1MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  51%|█████     | 131M/259M [00:08<00:06, 19.1MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  52%|█████▏    | 133M/259M [00:08<00:07, 16.8MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  52%|█████▏    | 135M/259M [00:08<00:07, 16.6MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  53%|█████▎    | 137M/259M [00:08<00:07, 17.0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  54%|█████▍    | 139M/259M [00:08<00:06, 18.4MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  55%|█████▍    | 141M/259M [00:08<00:06, 18.4MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  55%|█████▌    | 143M/259M [00:08<00:06, 17.6MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  56%|█████▌    | 145M/259M [00:08<00:06, 18.0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  57%|█████▋    | 147M/259M [00:09<00:06, 18.3MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  57%|█████▋    | 148M/259M [00:09<00:06, 18.0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  59%|█████▊    | 152M/259M [00:09<00:04, 21.6MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  59%|█████▉    | 154M/259M [00:09<00:05, 19.6MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  60%|██████    | 156M/259M [00:09<00:05, 19.4MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  61%|██████▏   | 159M/259M [00:09<00:04, 21.8MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  62%|██████▏   | 161M/259M [00:09<00:04, 21.3MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  63%|██████▎   | 163M/259M [00:09<00:04, 19.7MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  64%|██████▍   | 166M/259M [00:09<00:04, 21.3MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  65%|██████▌   | 168M/259M [00:10<00:04, 22.0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  66%|██████▌   | 170M/259M [00:10<00:04, 21.9MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  67%|██████▋   | 173M/259M [00:10<00:03, 22.7MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  68%|██████▊   | 175M/259M [00:10<00:03, 22.1MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  69%|██████▊   | 177M/259M [00:10<00:03, 22.0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  69%|██████▉   | 180M/259M [00:10<00:03, 21.9MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  70%|███████   | 182M/259M [00:10<00:03, 22.3MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  71%|███████   | 184M/259M [00:10<00:03, 21.7MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  72%|███████▏  | 186M/259M [00:10<00:03, 21.3MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  73%|███████▎  | 189M/259M [00:10<00:03, 20.9MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  74%|███████▍  | 191M/259M [00:11<00:03, 21.5MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  75%|███████▍  | 193M/259M [00:11<00:03, 21.3MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  76%|███████▌  | 196M/259M [00:11<00:02, 22.5MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  77%|███████▋  | 198M/259M [00:11<00:02, 22.5MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  77%|███████▋  | 200M/259M [00:11<00:02, 22.5MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  78%|███████▊  | 202M/259M [00:11<00:02, 22.0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  79%|███████▉  | 205M/259M [00:11<00:02, 22.8MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  80%|████████  | 207M/259M [00:11<00:02, 22.9MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  81%|████████  | 209M/259M [00:11<00:02, 21.9MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  82%|████████▏ | 212M/259M [00:12<00:02, 21.9MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  83%|████████▎ | 214M/259M [00:12<00:02, 21.4MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  84%|████████▍ | 217M/259M [00:12<00:01, 22.7MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  85%|████████▍ | 219M/259M [00:12<00:01, 21.0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  86%|████████▌ | 221M/259M [00:12<00:01, 21.1MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  86%|████████▋ | 223M/259M [00:12<00:01, 20.0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  87%|████████▋ | 226M/259M [00:12<00:01, 21.3MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  88%|████████▊ | 228M/259M [00:12<00:01, 21.6MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  89%|████████▉ | 230M/259M [00:12<00:01, 21.4MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  90%|█████████ | 233M/259M [00:12<00:01, 22.3MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  91%|█████████ | 235M/259M [00:13<00:01, 21.7MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  92%|█████████▏| 237M/259M [00:13<00:01, 21.0MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  93%|█████████▎| 240M/259M [00:13<00:00, 22.4MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  94%|█████████▍| 242M/259M [00:13<00:00, 23.1MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  95%|█████████▍| 245M/259M [00:13<00:00, 20.6MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  96%|█████████▌| 247M/259M [00:13<00:00, 21.3MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  97%|█████████▋| 250M/259M [00:13<00:00, 21.7MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  98%|█████████▊| 252M/259M [00:13<00:00, 22.4MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT:  98%|█████████▊| 254M/259M [00:13<00:00, 21.9MB/s]
# Downloading LanguageTool 6.8-SNAPSHOT: 100%|██████████| 259M/259M [00:14<00:00, 18.2MB/s]
# Models loaded successfully!

# %% [markdown]
# ##3.2 Text Generation Method
#
# - Input Formatting
#
# T5 requires task prefix: "paraphrase: <input_text> </s>"
#
#
# - Beam Search
#
# We use Beam Search decoding  for better output quality.:
#
#      - num_beams = 5
#      - max_length = 256
#      - early_stopping = True
#
# Beam Search improves output quality by exploring multiple possible sequences.

# %%
# Paraphrasing Function
#---------------------------

def paraphrase_text(input_text_str):

    input_text = "paraphrase: " + input_text_str + " </s>"

    encoding = tokenizer(
        input_text,
        return_tensors="pt"
    )

    outputs = model.generate(
        input_ids=encoding["input_ids"],
        attention_mask=encoding["attention_mask"],
        max_length=256,
        num_beams=5,
        num_return_sequences=1,
        early_stopping=True
    )

    paraphrased = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return paraphrased

# %% [markdown]
# ##**4. Evaluation Metrics**
# ---
#
# To measure the performance of the model, we use:
#
# ### 1. ROUGE Score
# - ROUGE-1: Word overlap
# - ROUGE-L: Longest sequence similarity
#
# Higher score → Higher lexical similarity
#
#
# ### 2. Semantic Similarity
#
# We compute cosine similarity between sentence embeddings.
#
# Range: 0 to 1
# > 0.85 indicates strong meaning preservation
#
#
# ### 3. Grammar Correction
#
# We use LanguageTool to:
# - Detect grammatical errors
# - Improve fluency

# %%
# Evaluation Function
#-----------------------
def evaluate_text(original, paraphrased):

    # Grammar Correction
    matches = grammar_tool.check(paraphrased)
    corrected_text = language_tool_python.utils.correct(paraphrased, matches)

    # ROUGE Score
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)
    rouge_scores = scorer.score(original, corrected_text)

    # Semantic Similarity
    embeddings = similarity_model.encode([original, corrected_text])
    similarity_score = util.cos_sim(embeddings[0], embeddings[1]).item()

    return corrected_text, rouge_scores, similarity_score

# %% [markdown]
# ##**5. Model Testing**
# ---
#
# Now we test the system using a sample input sentence.
#
# The system will:
#
# 1. Generate paraphrased text
# 2. Apply grammar correction
# 3. Calculate evaluation scores
# 4. Display results

# %%
# Run Example
#---------------
input_text = "Machine learning algorithms enable computers to learn and sudy from data and make predictions without being explicitly programmed."

paraphrased_output = paraphrase_text(input_text)

corrected_output, rouge_scores, similarity_score = evaluate_text(
    input_text, paraphrased_output
)

print("Original Text:\n", input_text)
print("\nParaphrased Text:\n", corrected_output)
print("\nROUGE Scores:\n", rouge_scores)
print("\nSemantic Similarity Score:\n", similarity_score)
# Out:
# Original Text:
#  Machine learning algorithms enable computers to learn and sudy from data and make predictions without being explicitly programmed.
#
# Paraphrased Text:
#  Machine learning algorithms enable computers to learn and make predictions without being explicitly programmed.
#
# ROUGE Scores:
#  {'rouge1': Score(precision=1.0, recall=0.7777777777777778, fmeasure=0.8750000000000001), 'rougeL': Score(precision=1.0, recall=0.7777777777777778, fmeasure=0.8750000000000001)}
#
# Semantic Similarity Score:
#  0.9345702528953552

# %% [markdown]
# ##6. Results
#
# The model successfully generates a paraphrased sentence while:
#
# - Preserving meaning
# - Maintaining grammatical correctness
# - Achieving high semantic similarity
#
# ROUGE scores show lexical overlap with variation,
# while cosine similarity confirms semantic preservation.
#
# ---
#
# ##7. Conclusion
#
# This project demonstrates how transformer-based models
# can effectively perform paraphrasing tasks.
#
# The integration of evaluation metrics ensures output quality and reliability.
#
# ---
#
# ## Future Improvements
#
# - Fine-tune on custom dataset
# - Add multiple paraphrase generation
# - Deploy as web application
# - Optimize performance using GPU
